# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd

from datetime import date
from keras import losses, optimizers
from keras.layers import Activation, Dense

from random import randrange
from sklearn.metrics import roc_auc_score
from sklearn.utils import class_weight

from tensorflow import keras
from tensorflow.keras import backend as K, layers, losses, metrics, optimizers
from tensorflow.keras.activations import elu, exponential, hard_sigmoid, linear,\
    relu, sigmoid, softmax, relu, tanh
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense
from tensorflow.keras.optimizers import Adadelta, Adam, Nadam, RMSprop, SGD
from tensorflow.keras.losses import binary_crossentropy, categorical_crossentropy,\
    logcosh, mean_absolute_error, mean_squared_error, poisson

from time import time
# Out:
# Using TensorFlow backend.

# %%
# Importing data
train_dataset = pd.read_csv(r'Workflow_new_SP_DR_shiny_FS_train_dataset.csv')
test_dataset = pd.read_csv(r'Workflow_new_SP_DR_shiny_FS_test_dataset.csv')

cols_to_drop = [
    'GRID_ID', 'Label', 'Signatory_NO_errors_last_5_days',
    'Signatory_NO_cases_last_5_days',
    'Signatory_NO_errors_last_month', 'Signatory_NO_cases_month']

train_data = train_dataset.drop(cols_to_drop, axis=1)
test_data = test_dataset.drop(cols_to_drop, axis=1)
train_labels = train_dataset.pop('Label')
test_labels = test_dataset.pop('Label')
# train_id = train_dataset.pop('GRID_ID')
# test_id = test_dataset.pop('GRID_ID')

# %%
def random_search(train_data,
                  train_labels,
                  test_data,
                  test_labels,
                  path,
                  max_iter=100,
                  max_hours=5,
                  target='Label',
                  min_auc=0.6):

    # set values for random search
    # early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)
    lr = np.arange(0.005, 0.1, 0.005)
    batch_size = np.array(range(20, 110, 10))
    units = [16, 32, 64, 128, 256]
    num_hidden_layers = [1, 2, 3, 4, 5, 6]
    epochs = [100, 150, 200, 250, 300, 350]
    dropout = np.arange(0, 0.5, 0.1)
    optimizers = [Adam, SGD]  # Nadam, RMSprop
    losses = ['binary_crossentropy']  # 'logcosh', 'mean_absolute_error', 'poisson', 'mean_squared_error'
    activation = [relu, tanh, elu]  # exponential
    last_activations = [sigmoid]
    early_stop = EarlyStopping(monitor='val_loss',
                               min_delta=0.01,
                               patience=30,
                               verbose=0,
                               mode='min',
                               restore_best_weights=True)
    class_weights = dict(enumerate(
        class_weight.compute_class_weight('balanced',
                                          np.unique(test_labels),
                                          test_labels)))

    # build model based on parameters choosen by talos optimalization
    # initialize lists to append with model results
    models_list = []
    results = []
    start_time = time()
    execution_time = 0
    i = 0
    while (execution_time < max_hours) and i != max_iter:
        curr_num_hidden_layers = num_hidden_layers[randrange(0,
                                                             len(num_hidden_layers),
                                                             1)]
        last_activation = last_activations[randrange(0,
                                                     len(last_activations),
                                                     1)]
        loss_function = losses[randrange(0, len(losses), 1)]
        optimizer_function = optimizers[randrange(0, len(optimizers), 1)]
        current_lr = lr[randrange(0, len(lr), 1)]
        current_epoch = epochs[randrange(0, len(epochs), 1)]
        current_batch_size = batch_size[randrange(0, len(batch_size), 1)]
        current_dropout = dropout[randrange(0, len(dropout), 1)]

        model = Sequential()
        model.add(Dense(units[randrange(0, len(units), 1)],
                        input_dim=train_data.shape[1],
                        activation=activation[randrange(0, len(activation), 1)]))
        model.add(Dropout(current_dropout))
        for j in range(curr_num_hidden_layers):
            model.add(Dense(units[randrange(0, len(units), 1)],
                            activation=activation[randrange(0, len(activation), 1)]))
        model.add(Dense(1,
                        activation=last_activation,
                        kernel_initializer='normal'))
        model.compile(loss=loss_function,
                      optimizer=optimizer_function(lr=current_lr),
                      metrics=['acc'])

        try:
            model.fit(train_data,
                      train_labels,
                      epochs=current_epoch,
                      batch_size=current_batch_size,
                      validation_split=0.2,
                      verbose=0,
                      callbacks=[early_stop])
        except Exception as e:
            error = 'Code: {}, Message: {}'.format(type(e).__name__, str(e))
            print(error)

        test_predictions = model.predict(test_data)
        predictions_df_test = pd.DataFrame(test_predictions)
        train_predictions = model.predict(train_data)
        predictions_df_train = pd.DataFrame(train_predictions)
        auc_train = roc_auc_score(train_labels, predictions_df_train)
        auc_test = roc_auc_score(test_labels, predictions_df_test)

        # for regression use val loss
        # auc = min(history.history['val_loss'])

        model_params = {'lr': current_lr,
                        'batch_size': current_batch_size,
                        'model_layers': model.get_config(),
                        'epochs': current_epoch,
                        'dropout': current_dropout,
                        'optimizer': str(optimizer_function),
                        'losses': loss_function,
                        'auc_test': auc_test,
                        'auc_train': auc_train,
                        'columns_used': test_data.columns.to_list()}
        # append results table with the latest model parameters and metrics
        results.append(model_params)

        if auc_test > min_auc:
            models_list.append(model)
        else:
            models_list.append(np.nan)
        i = i + 1
        execution_time = (time() - start_time) / 3600
        print("Iteration: {}. Time elapsed: {}".format(str(i),
                                                       round(execution_time, 4)))
    results_df = pd.DataFrame(results)
    results_df.to_csv(path + 'results_modelling_' + str(date.today()) + '.csv')
    return models_list, results_df

# %%
random_search_results_critical_LE = random_search(
    train_data, train_labels, test_data, test_labels,
    max_iter=400, max_hours=1.2,
    path=r'C:/Users/mmandziej001/Desktop/FCU/SCRIPTS/predictive_qc_lion_king/model_training/random_search_results/',
    min_auc=0.65)
# Out:
# Iteration: 1. Time elapsed: 0.0008
# Iteration: 2. Time elapsed: 0.0017
# Iteration: 3. Time elapsed: 0.0039
# Iteration: 4. Time elapsed: 0.0061
# Iteration: 5. Time elapsed: 0.0079
# Iteration: 6. Time elapsed: 0.0094
# Iteration: 7. Time elapsed: 0.0112
# Iteration: 8. Time elapsed: 0.0122
# Iteration: 9. Time elapsed: 0.0139
# Iteration: 10. Time elapsed: 0.0152
# Iteration: 11. Time elapsed: 0.0173
# Iteration: 12. Time elapsed: 0.0187
# Iteration: 13. Time elapsed: 0.0205
# Iteration: 14. Time elapsed: 0.0235
# Iteration: 15. Time elapsed: 0.0266
# Iteration: 16. Time elapsed: 0.0312
# Iteration: 17. Time elapsed: 0.0362
# Iteration: 18. Time elapsed: 0.0392
# Iteration: 19. Time elapsed: 0.0412
# Iteration: 20. Time elapsed: 0.0426
# Iteration: 21. Time elapsed: 0.0439
# Iteration: 22. Time elapsed: 0.0462
# Iteration: 23. Time elapsed: 0.0494
# Iteration: 24. Time elapsed: 0.0525
# Iteration: 25. Time elapsed: 0.0545
# Iteration: 26. Time elapsed: 0.0581
# Iteration: 27. Time elapsed: 0.0605
# Iteration: 28. Time elapsed: 0.0666
# Iteration: 29. Time elapsed: 0.0684
# Iteration: 30. Time elapsed: 0.0737
# Iteration: 31. Time elapsed: 0.0754
# Iteration: 32. Time elapsed: 0.0796
# Iteration: 33. Time elapsed: 0.0811
# Iteration: 34. Time elapsed: 0.085
# Iteration: 35. Time elapsed: 0.0869
# Iteration: 36. Time elapsed: 0.0893
# Iteration: 37. Time elapsed: 0.0942
# Iteration: 38. Time elapsed: 0.1009
# Iteration: 39. Time elapsed: 0.1072
# Iteration: 40. Time elapsed: 0.1108
# Iteration: 41. Time elapsed: 0.1156
# Iteration: 42. Time elapsed: 0.1186
# Iteration: 43. Time elapsed: 0.1211
# Iteration: 44. Time elapsed: 0.1231
# Iteration: 45. Time elapsed: 0.1247
# Iteration: 46. Time elapsed: 0.1264
# Iteration: 47. Time elapsed: 0.1284
# Iteration: 48. Time elapsed: 0.1312
# Iteration: 49. Time elapsed: 0.1326
# Iteration: 50. Time elapsed: 0.1336
# Iteration: 51. Time elapsed: 0.1353
# Iteration: 52. Time elapsed: 0.1371
# Iteration: 53. Time elapsed: 0.1411
# Iteration: 54. Time elapsed: 0.1425
# Iteration: 55. Time elapsed: 0.1447
# Iteration: 56. Time elapsed: 0.1474
# Iteration: 57. Time elapsed: 0.1511
# Iteration: 58. Time elapsed: 0.1534
# Iteration: 59. Time elapsed: 0.155
# Iteration: 60. Time elapsed: 0.1561
# Iteration: 61. Time elapsed: 0.1587
# Iteration: 62. Time elapsed: 0.1598
# Iteration: 63. Time elapsed: 0.1629
# Iteration: 64. Time elapsed: 0.165
# Iteration: 65. Time elapsed: 0.1671
# Iteration: 66. Time elapsed: 0.173
# Iteration: 67. Time elapsed: 0.1756
# Iteration: 68. Time elapsed: 0.1795
# Iteration: 69. Time elapsed: 0.1807
# Iteration: 70. Time elapsed: 0.1822
# Iteration: 71. Time elapsed: 0.1839
# Iteration: 72. Time elapsed: 0.1862
# Iteration: 73. Time elapsed: 0.1875
# Iteration: 74. Time elapsed: 0.1888
# Iteration: 75. Time elapsed: 0.1911
# Iteration: 76. Time elapsed: 0.1927
# Iteration: 77. Time elapsed: 0.1943
# Iteration: 78. Time elapsed: 0.2007
# Iteration: 79. Time elapsed: 0.2045
# Iteration: 80. Time elapsed: 0.2072
# Iteration: 81. Time elapsed: 0.2099
# Iteration: 82. Time elapsed: 0.2123
# Iteration: 83. Time elapsed: 0.2142
# Iteration: 84. Time elapsed: 0.2162
# Iteration: 85. Time elapsed: 0.2189
# Iteration: 86. Time elapsed: 0.2201
# Iteration: 87. Time elapsed: 0.2216
# Iteration: 88. Time elapsed: 0.2224
# Iteration: 89. Time elapsed: 0.2244
# Iteration: 90. Time elapsed: 0.2258
# Iteration: 91. Time elapsed: 0.227
# Iteration: 92. Time elapsed: 0.2289
# Iteration: 93. Time elapsed: 0.2303
# Iteration: 94. Time elapsed: 0.2315
# Iteration: 95. Time elapsed: 0.233
# Iteration: 96. Time elapsed: 0.2353
# Iteration: 97. Time elapsed: 0.2383
# Iteration: 98. Time elapsed: 0.2401
# Iteration: 99. Time elapsed: 0.2409
# Iteration: 100. Time elapsed: 0.2425
# Iteration: 101. Time elapsed: 0.2438
# Iteration: 102. Time elapsed: 0.2461
# Iteration: 103. Time elapsed: 0.2477
# Iteration: 104. Time elapsed: 0.25
# Iteration: 105. Time elapsed: 0.2515
# Iteration: 106. Time elapsed: 0.2529
# Iteration: 107. Time elapsed: 0.2546
# Iteration: 108. Time elapsed: 0.2586
# Iteration: 109. Time elapsed: 0.2606
# Iteration: 110. Time elapsed: 0.2624
# Iteration: 111. Time elapsed: 0.2642
# Iteration: 112. Time elapsed: 0.2668
# Iteration: 113. Time elapsed: 0.2716
# Iteration: 114. Time elapsed: 0.2752
# Iteration: 115. Time elapsed: 0.2776
# Iteration: 116. Time elapsed: 0.2801
# Iteration: 117. Time elapsed: 0.2822
# Iteration: 118. Time elapsed: 0.2848
# Iteration: 119. Time elapsed: 0.2867
# Iteration: 120. Time elapsed: 0.2887
# Iteration: 121. Time elapsed: 0.2925
# Iteration: 122. Time elapsed: 0.2967
# Iteration: 123. Time elapsed: 0.2992
# Iteration: 124. Time elapsed: 0.3013
# Iteration: 125. Time elapsed: 0.3031
# Iteration: 126. Time elapsed: 0.3052
# Iteration: 127. Time elapsed: 0.3079
# Iteration: 128. Time elapsed: 0.3099
# Iteration: 129. Time elapsed: 0.3134
# Iteration: 130. Time elapsed: 0.3157
# Iteration: 131. Time elapsed: 0.317
# Iteration: 132. Time elapsed: 0.3188
# Iteration: 133. Time elapsed: 0.3205
# Iteration: 134. Time elapsed: 0.3232
# Iteration: 135. Time elapsed: 0.325
# Iteration: 136. Time elapsed: 0.327
# Iteration: 137. Time elapsed: 0.3299
# Iteration: 138. Time elapsed: 0.3325
# Iteration: 139. Time elapsed: 0.3349
# Iteration: 140. Time elapsed: 0.337
# Iteration: 141. Time elapsed: 0.3387
# Iteration: 142. Time elapsed: 0.3407
# Iteration: 143. Time elapsed: 0.3423
# Iteration: 144. Time elapsed: 0.3442
# Iteration: 145. Time elapsed: 0.3467
# Iteration: 146. Time elapsed: 0.3492
# Iteration: 147. Time elapsed: 0.3514
# Iteration: 148. Time elapsed: 0.3525
# Iteration: 149. Time elapsed: 0.3558
# Iteration: 150. Time elapsed: 0.3581
# Iteration: 151. Time elapsed: 0.3608
# Iteration: 152. Time elapsed: 0.3645
# Iteration: 153. Time elapsed: 0.3662
# Iteration: 154. Time elapsed: 0.3728
# Iteration: 155. Time elapsed: 0.3755
# Iteration: 156. Time elapsed: 0.3812
# Iteration: 157. Time elapsed: 0.3832
# Iteration: 158. Time elapsed: 0.3857
# Iteration: 159. Time elapsed: 0.3896
# Iteration: 160. Time elapsed: 0.391
# Iteration: 161. Time elapsed: 0.3942
# Iteration: 162. Time elapsed: 0.3973
# Iteration: 163. Time elapsed: 0.4028
# Iteration: 164. Time elapsed: 0.4055
# Iteration: 165. Time elapsed: 0.407
# Iteration: 166. Time elapsed: 0.4085
# Iteration: 167. Time elapsed: 0.4113
# Iteration: 168. Time elapsed: 0.4139
# Iteration: 169. Time elapsed: 0.4177
# Iteration: 170. Time elapsed: 0.419
# Iteration: 171. Time elapsed: 0.421
# Iteration: 172. Time elapsed: 0.4233
# Iteration: 173. Time elapsed: 0.4248
# Iteration: 174. Time elapsed: 0.4265
# Iteration: 175. Time elapsed: 0.4286
# Iteration: 176. Time elapsed: 0.4305
# Iteration: 177. Time elapsed: 0.4341
# Iteration: 178. Time elapsed: 0.4359
# Iteration: 179. Time elapsed: 0.4378
# Iteration: 180. Time elapsed: 0.4409
# Iteration: 181. Time elapsed: 0.4436
# Iteration: 182. Time elapsed: 0.4459
# Iteration: 183. Time elapsed: 0.4477
# Iteration: 184. Time elapsed: 0.4505
# Iteration: 185. Time elapsed: 0.4538
# Iteration: 186. Time elapsed: 0.4582
# Iteration: 187. Time elapsed: 0.4627
# Iteration: 188. Time elapsed: 0.4658
# Iteration: 189. Time elapsed: 0.4671
# Iteration: 190. Time elapsed: 0.469
# Iteration: 191. Time elapsed: 0.4708
# Iteration: 192. Time elapsed: 0.4721
# Iteration: 193. Time elapsed: 0.4742
# Iteration: 194. Time elapsed: 0.4782
# Iteration: 195. Time elapsed: 0.4839
# Iteration: 196. Time elapsed: 0.4865
# Iteration: 197. Time elapsed: 0.4886
# Iteration: 198. Time elapsed: 0.4914
# Iteration: 199. Time elapsed: 0.4931
# Iteration: 200. Time elapsed: 0.4965
# Iteration: 201. Time elapsed: 0.5002
# Iteration: 202. Time elapsed: 0.5035
# Iteration: 203. Time elapsed: 0.5051
# Iteration: 204. Time elapsed: 0.5071
# Iteration: 205. Time elapsed: 0.5082
# Iteration: 206. Time elapsed: 0.5103
# Iteration: 207. Time elapsed: 0.5125
# Iteration: 208. Time elapsed: 0.5147
# Iteration: 209. Time elapsed: 0.5161
# Iteration: 210. Time elapsed: 0.5194
# Iteration: 211. Time elapsed: 0.5215
# Iteration: 212. Time elapsed: 0.5232
# Iteration: 213. Time elapsed: 0.5246
# Iteration: 214. Time elapsed: 0.527
# Iteration: 215. Time elapsed: 0.5285
# Iteration: 216. Time elapsed: 0.5308
# Iteration: 217. Time elapsed: 0.5334
# Iteration: 218. Time elapsed: 0.5356
# Iteration: 219. Time elapsed: 0.5407
# Iteration: 220. Time elapsed: 0.5493
# Iteration: 221. Time elapsed: 0.558
# Iteration: 222. Time elapsed: 0.567
# Iteration: 223. Time elapsed: 0.5698
# Iteration: 224. Time elapsed: 0.5726
# Iteration: 225. Time elapsed: 0.5753
# Iteration: 226. Time elapsed: 0.5769
# Iteration: 227. Time elapsed: 0.5806
# Iteration: 228. Time elapsed: 0.5825
# Iteration: 229. Time elapsed: 0.585
# Iteration: 230. Time elapsed: 0.5927
# Iteration: 231. Time elapsed: 0.5991
# Iteration: 232. Time elapsed: 0.6006
# Iteration: 233. Time elapsed: 0.603
# Iteration: 234. Time elapsed: 0.6063
# Iteration: 235. Time elapsed: 0.6097
# Iteration: 236. Time elapsed: 0.6122
# Iteration: 237. Time elapsed: 0.6168
# Iteration: 238. Time elapsed: 0.6189
# Iteration: 239. Time elapsed: 0.6219
# Iteration: 240. Time elapsed: 0.6244
# Iteration: 241. Time elapsed: 0.6283
# Iteration: 242. Time elapsed: 0.6312
# Iteration: 243. Time elapsed: 0.6347
# Iteration: 244. Time elapsed: 0.6401
# Iteration: 245. Time elapsed: 0.6424
# Iteration: 246. Time elapsed: 0.6456
# Iteration: 247. Time elapsed: 0.6476
# Iteration: 248. Time elapsed: 0.6511
# Iteration: 249. Time elapsed: 0.6573
# Iteration: 250. Time elapsed: 0.6619
# Iteration: 251. Time elapsed: 0.6656
# Iteration: 252. Time elapsed: 0.6682
# Iteration: 253. Time elapsed: 0.6708
# Iteration: 254. Time elapsed: 0.6732
# Iteration: 255. Time elapsed: 0.6757
# Iteration: 256. Time elapsed: 0.6781
# Iteration: 257. Time elapsed: 0.6796
# Iteration: 258. Time elapsed: 0.683
# Iteration: 259. Time elapsed: 0.6869
# Iteration: 260. Time elapsed: 0.6895
# Iteration: 261. Time elapsed: 0.6921
# Iteration: 262. Time elapsed: 0.6943
# Iteration: 263. Time elapsed: 0.6982
# Iteration: 264. Time elapsed: 0.7005
# Iteration: 265. Time elapsed: 0.7042
# Iteration: 266. Time elapsed: 0.7078
# Iteration: 267. Time elapsed: 0.7099
# Iteration: 268. Time elapsed: 0.7138
# Iteration: 269. Time elapsed: 0.7153
# Iteration: 270. Time elapsed: 0.7165
# Iteration: 271. Time elapsed: 0.718
# Iteration: 272. Time elapsed: 0.7242
# Iteration: 273. Time elapsed: 0.7267
# Iteration: 274. Time elapsed: 0.7283
# Iteration: 275. Time elapsed: 0.7301
# Iteration: 276. Time elapsed: 0.7325
# Iteration: 277. Time elapsed: 0.7339
# Iteration: 278. Time elapsed: 0.7366
# Iteration: 279. Time elapsed: 0.7381
# Iteration: 280. Time elapsed: 0.7411
# Iteration: 281. Time elapsed: 0.7429
# Iteration: 282. Time elapsed: 0.7453
# Iteration: 283. Time elapsed: 0.7482
# Iteration: 284. Time elapsed: 0.7507
# Iteration: 285. Time elapsed: 0.7527
# Iteration: 286. Time elapsed: 0.7553
# Iteration: 287. Time elapsed: 0.7573
# Iteration: 288. Time elapsed: 0.7589
# Iteration: 289. Time elapsed: 0.7626
# Iteration: 290. Time elapsed: 0.7644
# Iteration: 291. Time elapsed: 0.7679
# Iteration: 292. Time elapsed: 0.7697
# Iteration: 293. Time elapsed: 0.7708
# Iteration: 294. Time elapsed: 0.7733
# Iteration: 295. Time elapsed: 0.7769
# Iteration: 296. Time elapsed: 0.7794
# Iteration: 297. Time elapsed: 0.7816
# Iteration: 298. Time elapsed: 0.7845
# Iteration: 299. Time elapsed: 0.7857
# Iteration: 300. Time elapsed: 0.7883
# Iteration: 301. Time elapsed: 0.7904
# Iteration: 302. Time elapsed: 0.7917
# Iteration: 303. Time elapsed: 0.7936
# Iteration: 304. Time elapsed: 0.7957
# Iteration: 305. Time elapsed: 0.797
# Iteration: 306. Time elapsed: 0.7989
# Iteration: 307. Time elapsed: 0.8005
# Iteration: 308. Time elapsed: 0.8023
# Iteration: 309. Time elapsed: 0.8044
# Iteration: 310. Time elapsed: 0.8061
# Iteration: 311. Time elapsed: 0.8114
# Iteration: 312. Time elapsed: 0.8136
# Iteration: 313. Time elapsed: 0.816
# Iteration: 314. Time elapsed: 0.8186
# Iteration: 315. Time elapsed: 0.8205
# Iteration: 316. Time elapsed: 0.8227
# Iteration: 317. Time elapsed: 0.8237
# Iteration: 318. Time elapsed: 0.8264
# Iteration: 319. Time elapsed: 0.8296
# Iteration: 320. Time elapsed: 0.8326
# Iteration: 321. Time elapsed: 0.8342
# Iteration: 322. Time elapsed: 0.8355
# Iteration: 323. Time elapsed: 0.8398
# Iteration: 324. Time elapsed: 0.8415
# Iteration: 325. Time elapsed: 0.8443
# Iteration: 326. Time elapsed: 0.8468
# Iteration: 327. Time elapsed: 0.8486
# Iteration: 328. Time elapsed: 0.8518
# Iteration: 329. Time elapsed: 0.8544
# Iteration: 330. Time elapsed: 0.8569
# Iteration: 331. Time elapsed: 0.8595
# Iteration: 332. Time elapsed: 0.8641
# Iteration: 333. Time elapsed: 0.8664
# Iteration: 334. Time elapsed: 0.8712
# Iteration: 335. Time elapsed: 0.8743
# Iteration: 336. Time elapsed: 0.8762
# Iteration: 337. Time elapsed: 0.8787
# Iteration: 338. Time elapsed: 0.8812
# Iteration: 339. Time elapsed: 0.8842
# Iteration: 340. Time elapsed: 0.8862
# Iteration: 341. Time elapsed: 0.8884
# Iteration: 342. Time elapsed: 0.8896
# Iteration: 343. Time elapsed: 0.8917
# Iteration: 344. Time elapsed: 0.8947
# Iteration: 345. Time elapsed: 0.8977
# Iteration: 346. Time elapsed: 0.9002
# Iteration: 347. Time elapsed: 0.9035
# Iteration: 348. Time elapsed: 0.9064
# Iteration: 349. Time elapsed: 0.9082
# Iteration: 350. Time elapsed: 0.9107
# Iteration: 351. Time elapsed: 0.9137
# Iteration: 352. Time elapsed: 0.9164
# Iteration: 353. Time elapsed: 0.9182
# Iteration: 354. Time elapsed: 0.9201
# Iteration: 355. Time elapsed: 0.9227
# Iteration: 356. Time elapsed: 0.9243
# Iteration: 357. Time elapsed: 0.9267
# Iteration: 358. Time elapsed: 0.9293
# Iteration: 359. Time elapsed: 0.9315
# Iteration: 360. Time elapsed: 0.9339
# Iteration: 361. Time elapsed: 0.9353
# Iteration: 362. Time elapsed: 0.9365
# Iteration: 363. Time elapsed: 0.9378
# Iteration: 364. Time elapsed: 0.94
# Iteration: 365. Time elapsed: 0.9417
# Iteration: 366. Time elapsed: 0.9437
# Iteration: 367. Time elapsed: 0.9477
# Iteration: 368. Time elapsed: 0.9509
# Iteration: 369. Time elapsed: 0.9534
# Iteration: 370. Time elapsed: 0.9551
# Iteration: 371. Time elapsed: 0.9568
# Iteration: 372. Time elapsed: 0.9592
# Iteration: 373. Time elapsed: 0.9615
# Iteration: 374. Time elapsed: 0.9631
# Iteration: 375. Time elapsed: 0.9651
# Iteration: 376. Time elapsed: 0.9691
# Iteration: 377. Time elapsed: 0.9713
# Iteration: 378. Time elapsed: 0.9746
# Iteration: 379. Time elapsed: 0.9769
# Iteration: 380. Time elapsed: 0.9793
# Iteration: 381. Time elapsed: 0.9811
# Iteration: 382. Time elapsed: 0.983
# Iteration: 383. Time elapsed: 0.9875
# Iteration: 384. Time elapsed: 0.9908
# Iteration: 385. Time elapsed: 0.9936
# Iteration: 386. Time elapsed: 0.9971
# Iteration: 387. Time elapsed: 0.9993
# Iteration: 388. Time elapsed: 1.0019
# Iteration: 389. Time elapsed: 1.0043
# Iteration: 390. Time elapsed: 1.0068
# Iteration: 391. Time elapsed: 1.0103
# Iteration: 392. Time elapsed: 1.0126
# Iteration: 393. Time elapsed: 1.0141
# Iteration: 394. Time elapsed: 1.0167
# Iteration: 395. Time elapsed: 1.0205
# Iteration: 396. Time elapsed: 1.0233
# Iteration: 397. Time elapsed: 1.0249
# Iteration: 398. Time elapsed: 1.0267
# Iteration: 399. Time elapsed: 1.0289
# Iteration: 400. Time elapsed: 1.0315

# %%
random_search_results_lion=random_search_results_critical_LE

# %%
random_search_results_lion[0][46]
# Out:
# nan

# %%
best_model = random_search_results_lion[0][46]
best_model.summary()

# %%
model = Sequential()
model.add(Dense(64, input_dim= train_data.shape[1], activation=tanh))
#create a loop making a new dense layer for the amount passed to this model.
#naming the layers helps avoid tensorflow error deep in the stack trace.
model.add(Dense(16,activation=tanh))
model.add(Dropout(0.1))

#model.add(Dropout(0.4))
#model.add(Dense(32,activation=sigmoid))
model.add(Dense(32,activation=relu))
#model.add(Dense(64,activation=relu))
model.add(Dense(32,activation=relu))
model.add(Dense(1,activation=sigmoid,kernel_initializer='normal'))
#add our classification layer.


#setup our optimizer and compile
model.compile(optimizer=SGD(lr=0.005), loss='binary_crossentropy',
             metrics=['acc'])

# %%
for layer in best_model.layers:
    try:
        print(layer.input_shape)
    except:
        print('Dropout')
# Out:
# (None, 40)
# (None, 64)
# (None, 64)
# (None, 128)
# (None, 256)
# (None, 64)

# %%
best_model.save(r'C:/Users/mmandziej001/Desktop/FCU/SCRIPTS/predictive_qc_lion_king/model_training/random_search_results/final_model_DR.h5')
